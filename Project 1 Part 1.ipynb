# %% [markdown]
# ### Lonet Joseph
# ### October 13, 2023
# ### Explore the Project 1 dataset using Python, and perform data cleaning using pandas.

# %% [markdown]
# ### Data Exploration

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\jlone\\OneDrive\Desktop\\CCM Computing Entry Survey - Fall 2022.csv")

# %%
# Basic properties and summary statistics

# Shape of the DataFrame
shape_info = df.shape

# Information about the DataFrame
df_info = df.info()

# Descriptive statistics of the DataFrame
desc_stats = df.describe(include='all')

shape_info, desc_stats.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 92 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        453 non-null    object
#  1   Which course are you enrolled in?                                                                                                                                                                                                                                449 non-null    object
#  2   How did you hear about County College of Morris? [CCM Web site]                                                                                                                                                                                                  453 non-null    object
#  3   How did you hear about County College of Morris? [Social Media]                                                                                                                                                                                                  453 non-null    object
#  4   How did you hear about County College of Morris? [Community Event]                                                                                                                                                                                               453 non-null    object
#  5   How did you hear about County College of Morris? [Family member or friend]                                                                                                                                                                                       453 non-null    object
#  6   How did you hear about County College of Morris? [Current CCM student]                                                                                                                                                                                           453 non-null    object
#  7   How did you hear about County College of Morris? [CCM Alumni]                                                                                                                                                                                                    453 non-null    object
#  8   How did you hear about County College of Morris? [High School Teacher]                                                                                                                                                                                           453 non-null    object
#  9   How did you hear about County College of Morris? [High School Counselor]                                                                                                                                                                                         453 non-null    object
#  10  How did you hear about County College of Morris? [In-app advertisement]                                                                                                                                                                                          453 non-null    object
#  11  How did you hear about County College of Morris? [Employer]                                                                                                                                                                                                      453 non-null    object
#  12  How did you hear about County College of Morris? [Billboard]                                                                                                                                                                                                     453 non-null    object
#  13  How did you hear about County College of Morris? [Television]                                                                                                                                                                                                    453 non-null    object
#  14  How did you hear about County College of Morris? [Radio]                                                                                                                                                                                                         453 non-null    object
#  15  How did you hear about County College of Morris? [Home mailer]                                                                                                                                                                                                   453 non-null    object
#  16  How did you hear about County College of Morris? [Other]                                                                                                                                                                                                         453 non-null    object
#  17  To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]                                                                                                                                                      417 non-null    object
#  18  To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]                                                                                                                                                 430 non-null    object
#  19  To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]                                                                                                                                                   429 non-null    object
#  20  To what extent did the following impact your decision to attend County College of Morris? [Online offerings]                                                                                                                                                     404 non-null    object
#  21  To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]                                                                                                                                               401 non-null    object
#  22  To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]                                                                                                                                                        379 non-null    object
#  23  To what extent did the following impact your decision to attend County College of Morris? [College reputation]                                                                                                                                                   403 non-null    object
#  24  To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]                                                                                                                                                        390 non-null    object
#  25  To what extent did the following impact your decision to attend County College of Morris? [Scholarships]                                                                                                                                                         387 non-null    object
#  26  To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]                                                                                                                                                    403 non-null    object
#  27  To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]                                                                                                                                       398 non-null    object
#  28  To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]                                                                                                                                         350 non-null    object
#  29  To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]                                                                                                                               337 non-null    object
#  30  To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]                                                                                                                                                     332 non-null    object
#  31  To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]                                                                                                                   422 non-null    object
#  32  To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]                                                                                                                              364 non-null    object
#  33  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]                                                   453 non-null    object
#  34  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]                                         453 non-null    object
#  35  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]                                453 non-null    object
#  36  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]                 453 non-null    object
#  37  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]                                               453 non-null    object
#  38  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]                                        453 non-null    object
#  39  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]                             453 non-null    object
#  40  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]                                           453 non-null    object
#  41  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]  453 non-null    object
#  42  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]                        453 non-null    object
#  43  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]                             453 non-null    object
#  44  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]                                    453 non-null    object
#  45  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]                                  453 non-null    object
#  46  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]                                           453 non-null    object
#  47  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]                                           453 non-null    object
#  48  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]                                           453 non-null    object
#  49  Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]                                                 453 non-null    object
#  50  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]                                                                                                     394 non-null    object
#  51  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]                                                                                              372 non-null    object
#  52  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]                              376 non-null    object
#  53  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]                                                                                             358 non-null    object
#  54  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]                                                                                                  359 non-null    object
#  55  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]                                                                                                                  358 non-null    object
#  56  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]                                                                                                      364 non-null    object
#  57  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]                                                                                                             407 non-null    object
#  58  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]                                                                                        396 non-null    object
#  59  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]                                                                                              391 non-null    object
#  60  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]                                                                                                                     369 non-null    object
#  61  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]                                                                                                                    381 non-null    object
#  62  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]                                                                                                                     381 non-null    object
#  63  To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]                                                                                                                                  341 non-null    object
#  64  What degree program are you currently enrolled in?                                                                                                                                                                                                               453 non-null    object
#  65  What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]                                                                                                                                                         335 non-null    object
#  66  What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor's level program]                                                                                                                                                        335 non-null    object
#  67  What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]                                                                                                                          335 non-null    object
#  68  What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]                                                                                                                                                                          335 non-null    object
#  69  What motivated you to seek a computing degree/certificate at CCM?  [Career Change]                                                                                                                                                                               335 non-null    object
#  70  What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]                                                                                                                                                                    335 non-null    object
#  71  What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]                                                                                                                                                                            335 non-null    object
#  72  What motivated you to seek a computing degree/certificate at CCM?  [Relocation]                                                                                                                                                                                  335 non-null    object
#  73  What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]                                                                                                                                                            335 non-null    object
#  74  What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]                                                                                                                                                                  335 non-null    object
#  75  What motivated you to seek a computing degree/certificate at CCM?  [Financial]                                                                                                                                                                                   335 non-null    object
#  76  What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]                                                                                                                                                                         335 non-null    object
#  77  Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]                                                                                                                                 335 non-null    object
#  78  Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]                                                                                                                                            335 non-null    object
#  79  Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]                                                                                                                           335 non-null    object
#  80  Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]                                                                                                                                                 335 non-null    object
#  81  Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]                                                                                                                                          335 non-null    object
#  82  Did you receive information about the CCM computing programs from any of the following sources? [Employer]                                                                                                                                                       335 non-null    object
#  83  Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]                                                                                                                                      335 non-null    object
#  84  Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]                                                                                                                               335 non-null    object
#  85  Did you receive information about the CCM computing programs from any of the following sources? [Other]                                                                                                                                                          335 non-null    object
#  86  Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.                                                                                           334 non-null    object
#  87  On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?                                                                                                              118 non-null    float64
#  88  Please explain your answer to the question above.  Why or why not would you be interested in taking another computing class?                                                                                                                                     118 non-null    object
#  89  Gender                                                                                                                                                                                                                                                           453 non-null    object
#  90  Race/ethnicity                                                                                                                                                                                                                                                   453 non-null    object
#  91  Age                                                                                                                                                                                                                                                              453 non-null    object
# dtypes: float64(1), object(91)
# memory usage: 325.7+ KB
# ((453, 92),
#                          Timestamp Which course are you enrolled in?  \
#  count                         453                               449
#  unique                        450                                 5
#  top     2022/10/05 9:38:11 AM AST        CMP 128 Computer Science I
#  freq                            2                               268
#  mean                          NaN                               NaN
#
#         How did you hear about County College of Morris? [CCM Web site]  \
#  count                                                 453
#  unique                                                  3
#  top                                                    No
#  freq                                                  265
#  mean                                                  NaN
#
#         How did you hear about County College of Morris? [Social Media]  \
#  count                                                 453
#  unique                                                  3
#  top                                                    No
#  freq                                                  326
#  mean                                                  NaN
#
#         How did you hear about County College of Morris? [Community Event]  \
#  count                                                 453
#  unique                                                  3
#  top                                                    No
#  freq                                                  337
#  mean                                                  NaN
#
#         How did you hear about County College of Morris? [Family member or friend]  \
#  count                                                 453
#  unique                                                  3
#  top                                                   Yes
#  freq                                                  319
#  mean                                                  NaN
#
#         How did you hear about County College of Morris? [Current CCM student]  \
#  count                                                 453
#  unique                                                  3
#  top                                                    No
#  freq                                                  240
#  mean                                                  NaN
#
#         How did you hear about County College of Morris? [CCM Alumni]  \
#  count                                                 453
#  unique                                                  3
#  top                                                    No
#  freq                                                  282
#  mean                                                  NaN
#
#         How did you hear about County College of Morris? [High School Teacher]  \
#  count                                                 453
#  unique                                                  3
#  top                                                   Yes
#  freq                                                  216
#  mean                                                  NaN
#
#         How did you hear about County College of Morris? [High School Counselor]  \
#  count                                                 453
#  unique                                                  3
#  top                                                   Yes
#  freq                                                  234
#  mean                                                  NaN
#
#          ...  \
#  count   ...
#  unique  ...
#  top     ...
#  freq    ...
#  mean    ...
#
#         Did you receive information about the CCM computing programs from any of the following sources? [Employer]  \
#  count                                                 335
#  unique                                                  3
#  top                                                    No
#  freq                                                  304
#  mean                                                  NaN
#
#         Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]  \
#  count                                                 335
#  unique                                                  3
#  top                                                    No
#  freq                                                  301
#  mean                                                  NaN
#
#         Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]  \
#  count                                                 335
#  unique                                                  3
#  top                                                    No
#  freq                                                  298
#  mean                                                  NaN
#
#         Did you receive information about the CCM computing programs from any of the following sources? [Other]  \
#  count                                                 335
#  unique                                                  3
#  top                                                    No
#  freq                                                  248
#  mean                                                  NaN
#
#         Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.  \
#  count                                                 334
#  unique                                                 45
#  top                                          First Choice
#  freq                                                  220
#  mean                                                  NaN
#
#         On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?  \
#  count                                           118.00000
#  unique                                                NaN
#  top                                                   NaN
#  freq                                                  NaN
#  mean                                              3.59322
#
#         Please explain your answer to the question above.  Why or why not would you be interested in taking another computing class?  \
#  count                                                 118
#  unique                                                117
#  top                 I would like to learn about computing
#  freq                                                    2
#  mean                                                  NaN
#
#         Gender   Race/ethnicity            Age
#  count     453              453             453
#  unique      5               24               6
#  top       Man  White/Caucasian  18 and younger
#  freq      352              200             166
#  mean      NaN              NaN             NaN
#
#  [5 rows x 92 columns])

# %%
 # Listing all column names
column_names = df.columns.tolist()
column_names
# Out:
# ['Timestamp',
#  'Which course are you enrolled in?',
#  'How did you hear about County College of Morris? [CCM Web site]',
#  'How did you hear about County College of Morris? [Social Media]',
#  'How did you hear about County College of Morris? [Community Event]',
#  'How did you hear about County College of Morris? [Family member or friend]',
#  'How did you hear about County College of Morris? [Current CCM student]',
#  'How did you hear about County College of Morris? [CCM Alumni]',
#  'How did you hear about County College of Morris? [High School Teacher]',
#  'How did you hear about County College of Morris? [High School Counselor]',
#  'How did you hear about County College of Morris? [In-app advertisement]',
#  'How did you hear about County College of Morris? [Employer]',
#  'How did you hear about County College of Morris? [Billboard]',
#  'How did you hear about County College of Morris? [Television]',
#  'How did you hear about County College of Morris? [Radio]',
#  'How did you hear about County College of Morris? [Home mailer]',
#  'How did you hear about County College of Morris? [Other]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]',
#  'To what extent did the following impact your decision to attend County College of Morris? [College reputation]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]',
#  'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]',
#  'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]',
#  'What degree program are you currently enrolled in?',
#  'What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]',
#  "What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor's level program]",
#  'What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [Career Change]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [Relocation]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [Financial]',
#  'What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [Employer]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]',
#  'Did you receive information about the CCM computing programs from any of the following sources? [Other]',
#  'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.',
#  'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?',
#  'Please explain your answer to the question above.  Why or why not would you be interested in taking another computing class?',
#  'Gender',
#  'Race/ethnicity',
#  'Age ']

# %% [markdown]
# ### Data Cleaning

# %%
 # Renaming the columns

# Simplifying "How did you hear about County College of Morris?" columns
hear_about_ccm_mapping = {
    col: 'heard_from_' + col.split('[')[-1].split(']')[0].replace(' ', '_').lower() for col in df.columns if 'How did you hear about County College of Morris?' in col
}

# Simplifying "To what extent did the following impact your decision to attend County College of Morris?" columns
impact_decision_mapping = {
    col: 'impact_' + col.split('[')[-1].split(']')[0].replace(' ', '_').lower() for col in df.columns if 'To what extent did the following impact your decision to attend County College of Morris?' in col
}

# Simplifying "What motivated you to seek a computing degree/certificate at CCM?" columns
motivation_mapping = {
    col: 'motivation_' + col.split('[')[-1].split(']')[0].replace(' ', '_').lower() for col in df.columns if 'What motivated you to seek a computing degree/certificate at CCM?' in col
}

# Simplifying "Did you receive information about the CCM computing programs from any of the following sources?" columns
info_sources_mapping = {
    col: 'info_from_' + col.split('[')[-1].split(']')[0].replace(' ', '_').lower() for col in df.columns if 'Did you receive information about the CCM computing programs from any of the following sources?' in col
}

# Manually renaming some columns for brevity and clarity
manual_mapping = {
    'Which course are you enrolled in?': 'course_enrolled',
    'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.': 'major_change_details',
    'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?': 'interest_in_computing_classes',
    'Please explain your answer to the question above.  Why or why not would you be interested in taking another computing class?': 'reason_interest_in_computing',
    'Gender': 'gender',
    'Race/ethnicity': 'race_ethnicity',
    'Age ': 'age'  # Note: The original column name has an extra space
}

# Combining all renaming mappings
all_mappings = {**hear_about_ccm_mapping, **impact_decision_mapping, **motivation_mapping, **info_sources_mapping, **manual_mapping}

# Applying the renaming
df_renamed = df.rename(columns=all_mappings)

# Displaying the renamed columns
df_renamed.columns.tolist()
# Out:
# ['Timestamp',
#  'course_enrolled',
#  'heard_from_ccm_web_site',
#  'heard_from_social_media',
#  'heard_from_community_event',
#  'heard_from_family_member_or_friend',
#  'heard_from_current_ccm_student',
#  'heard_from_ccm_alumni',
#  'heard_from_high_school_teacher',
#  'heard_from_high_school_counselor',
#  'heard_from_in-app_advertisement',
#  'heard_from_employer',
#  'heard_from_billboard',
#  'heard_from_television',
#  'heard_from_radio',
#  'heard_from_home_mailer',
#  'heard_from_other',
#  'impact_affordable_cost',
#  'impact_location/convenience',
#  'impact_choice_of_programs',
#  'impact_online_offerings',
#  'impact_family/friend_referral',
#  'impact_faculty/staff',
#  'impact_college_reputation',
#  'impact_financial_aid',
#  'impact_scholarships',
#  'impact_small_class_sizes',
#  'impact_extra-curricular_opportunities',
#  'impact_accepted_my_transfer_credits',
#  'impact_negative_experience_at_another_college',
#  'impact_nj_stars_program',
#  'impact_ability_to_transfer_ccm_credits_to_a_4-year_school',
#  'impact_get_college_credit_while_in_high_school',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]',
#  'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]',
#  'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]',
#  'What degree program are you currently enrolled in?',
#  'motivation_to_get_a_job_in_the_computing_field',
#  "motivation_transfer_to_bachelor's_level_program",
#  'motivation_transfer_credits_back_to_hs_degree_(sharetime,_challenger_program)',
#  'motivation_career_advancement',
#  'motivation_career_change',
#  'motivation_professional_development',
#  'motivation_job_displacement',
#  'motivation_relocation',
#  'motivation_to_keep_current_in_tech_industry',
#  'motivation_it_industry_certifications',
#  'motivation_financial',
#  'motivation_personal_enrichment',
#  'info_from_high_school_guidance_counselor',
#  'info_from_high_school_teacher',
#  'info_from_ccm_information_technologies_website',
#  'info_from_ccm_admissions',
#  'info_from_ccm_advisor/counselor',
#  'info_from_employer',
#  'info_from_ccm_workforce_development',
#  'info_from_nj_workforce_development_program',
#  'info_from_other',
#  'major_change_details',
#  'interest_in_computing_classes',
#  'reason_interest_in_computing',
#  'gender',
#  'race_ethnicity',
#  'age']

# %%
# Calculating percentage of missing values for each column
missing_percentage = (df.isnull().sum() / len(df)) * 100

# Displaying columns with their missing percentage
missing_percentage.sort_values(ascending=False)
# Out:
# Please explain your answer to the question above.  Why or why not would you be interested in taking another computing class?                                                                                                            73.951435
# On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?                                                                                     73.951435
# To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]                                                                                                                            26.710817
# Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.                                                                  26.269316
# What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor's level program]                                                                                                                               26.048565
#                                                                                                                                                                                                                                           ...
# Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]     0.000000
# Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]            0.000000
# Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]          0.000000
# Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]                   0.000000
# Age                                                                                                                                                                                                                                      0.000000
# Length: 92, dtype: float64

# %%
# Categorizing columns based on relevance

# Highly Relevant columns
highly_relevant = [
    'course_enrolled',
    'heard_from_ccm_web_site',
    'heard_from_social_media',
    'heard_from_community_event',
    'heard_from_family_member_or_friend',
    'heard_from_current_ccm_student',
    'heard_from_ccm_alumni',
    'heard_from_high_school_teacher',
    'heard_from_high_school_counselor',
    'major_change_details',
    'motivation_to_get_a_job_in_the_computing_field',
    'motivation_transfer_to_bachelor\'s_level_program',
    'motivation_career_advancement',
    'motivation_career_change',
    'motivation_professional_development',
    'info_from_high_school_guidance_counselor',
    'info_from_high_school_teacher',
    'info_from_ccm_information_technologies_website',
    'info_from_ccm_admissions',
    'info_from_ccm_advisor/counselor',
    'gender',
    'race_ethnicity',
    'age'
]

# Potentially Relevant columns
potentially_relevant = [
    'impact_affordable_cost',
    'impact_location/convenience',
    'impact_choice_of_programs',
    'impact_online_offerings',
    'impact_family/friend_referral',
    'impact_college_reputation',
    'interest_in_computing_classes',
    'reason_interest_in_computing'
]

# Less Relevant columns
less_relevant = [
    'Timestamp',
    'info_from_employer',
    'info_from_ccm_workforce_development',
    'info_from_nj_workforce_development_program',
    'info_from_other'
]

# Irrelevant columns are those that are not in the above categories
irrelevant = [col for col in df_renamed.columns if col not in (highly_relevant + potentially_relevant + less_relevant)]

categorized_columns = {
    'Highly Relevant': highly_relevant,
    'Potentially Relevant': potentially_relevant,
    'Less Relevant': less_relevant,
    'Irrelevant': irrelevant
}

categorized_columns
# Out:
# {'Highly Relevant': ['course_enrolled',
#   'heard_from_ccm_web_site',
#   'heard_from_social_media',
#   'heard_from_community_event',
#   'heard_from_family_member_or_friend',
#   'heard_from_current_ccm_student',
#   'heard_from_ccm_alumni',
#   'heard_from_high_school_teacher',
#   'heard_from_high_school_counselor',
#   'major_change_details',
#   'motivation_to_get_a_job_in_the_computing_field',
#   "motivation_transfer_to_bachelor's_level_program",
#   'motivation_career_advancement',
#   'motivation_career_change',
#   'motivation_professional_development',
#   'info_from_high_school_guidance_counselor',
#   'info_from_high_school_teacher',
#   'info_from_ccm_information_technologies_website',
#   'info_from_ccm_admissions',
#   'info_from_ccm_advisor/counselor',
#   'gender',
#   'race_ethnicity',
#   'age'],
#  'Potentially Relevant': ['impact_affordable_cost',
#   'impact_location/convenience',
#   'impact_choice_of_programs',
#   'impact_online_offerings',
#   'impact_family/friend_referral',
#   'impact_college_reputation',
#   'interest_in_computing_classes',
#   'reason_interest_in_computing'],
#  'Less Relevant': ['Timestamp',
#   'info_from_employer',
#   'info_from_ccm_workforce_development',
#   'info_from_nj_workforce_development_program',
#   'info_from_other'],
#  'Irrelevant': ['heard_from_in-app_advertisement',
#   'heard_from_employer',
#   'heard_from_billboard',
#   'heard_from_television',
#   'heard_from_radio',
#   'heard_from_home_mailer',
#   'heard_from_other',
#   'impact_faculty/staff',
#   'impact_financial_aid',
#   'impact_scholarships',
#   'impact_small_class_sizes',
#   'impact_extra-curricular_opportunities',
#   'impact_accepted_my_transfer_credits',
#   'impact_negative_experience_at_another_college',
#   'impact_nj_stars_program',
#   'impact_ability_to_transfer_ccm_credits_to_a_4-year_school',
#   'impact_get_college_credit_while_in_high_school',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]',
#   'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Hour of Code]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]',
#   'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]',
#   'What degree program are you currently enrolled in?',
#   'motivation_transfer_credits_back_to_hs_degree_(sharetime,_challenger_program)',
#   'motivation_job_displacement',
#   'motivation_relocation',
#   'motivation_to_keep_current_in_tech_industry',
#   'motivation_it_industry_certifications',
#   'motivation_financial',
#   'motivation_personal_enrichment']}

# %%
# Dropping the irrelevant columns
df_cleaned = df_renamed.drop(columns=irrelevant + less_relevant)

# Displaying the first few rows of the cleaned dataframe
df_cleaned.head()
# Out:
#               course_enrolled heard_from_ccm_web_site heard_from_social_media  \
# 0  CMP 128 Computer Science I                     Yes                     Yes
# 1                         NaN                      No                      No
# 2  CMP 128 Computer Science I                      No                      No
# 3  CMP 128 Computer Science I                      No                      No
# 4  CMP 128 Computer Science I                     Yes                      No
#
#   heard_from_community_event heard_from_family_member_or_friend  \
# 0                        Yes                                Yes
# 1                         No                                 No
# 2                         No                                 No
# 3                        Yes                                 No
# 4                         No                                Yes
#
#   heard_from_current_ccm_student heard_from_ccm_alumni  \
# 0                             No                    No
# 1                            Yes                    No
# 2                             No                    No
# 3                            Yes                    No
# 4                             No                    No
#
#   heard_from_high_school_teacher heard_from_high_school_counselor  \
# 0                            Yes                              Yes
# 1                             No                               No
# 2                            Yes                              Yes
# 3                             No                               No
# 4                            Yes                               No
#
#   impact_affordable_cost  ... info_from_high_school_teacher  \
# 0            Some Impact  ...                           Yes
# 1            Some Impact  ...                            No
# 2            High Impact  ...                           NaN
# 3            High Impact  ...                           Yes
# 4                    NaN  ...                            No
#
#   info_from_ccm_information_technologies_website info_from_ccm_admissions  \
# 0                                            Yes                      Yes
# 1                                            Yes                       No
# 2                                            NaN                      NaN
# 3                                             No                      Yes
# 4                                             No                       No
#
#   info_from_ccm_advisor/counselor major_change_details  \
# 0                             Yes         First Choice
# 1                             Yes         First Choice
# 2                             NaN                  NaN
# 3                              No         First Choice
# 4                              No         First Choice
#
#   interest_in_computing_classes  \
# 0                           NaN
# 1                           NaN
# 2                           1.0
# 3                           NaN
# 4                           NaN
#
#                         reason_interest_in_computing gender   race_ethnicity  \
# 0                                                NaN    Man  White/Caucasian
# 1                                                NaN    Man  White/Caucasian
# 2  Im really only taking this class for the requi...  Woman  White/Caucasian
# 3                                                NaN    Man            Asian
# 4                                                NaN    Man  White/Caucasian
#
#               age
# 0           19-20
# 1           25-34
# 2           19-20
# 3  18 and younger
# 4           25-34
#
# [5 rows x 31 columns]

# %%
# Checking unique values in 'race_ethnicity' and 'course_enrolled' columns
unique_race = df_cleaned['race_ethnicity'].unique()
unique_course = df_cleaned['course_enrolled'].unique()

unique_race, unique_course
# Out:
# (array(['White/Caucasian', 'Asian', 'Choose not to reply',
#         'Hispanic or Latino;White/Caucasian', 'Hispanic or Latino',
#         'American Indian/Native American/Alaska Native', 'Multi-Racial',
#         'American Indian/Native American/Alaska Native;Multi-Racial',
#         'Black/African American;White/Caucasian;Multi-Racial',
#         'Black/African American',
#         'Hispanic or Latino;American Indian/Native American/Alaska Native;Asian;Black/African American;Native Hawaiian/Other Pacific Islander;White/Caucasian',
#         'Hispanic or Latino;Black/African American',
#         'White/Caucasian;Multi-Racial',
#         'Asian;Native Hawaiian/Other Pacific Islander;White/Caucasian',
#         'Asian;White/Caucasian', 'Hispanic or Latino;Multi-Racial',
#         'Hispanic or Latino;American Indian/Native American/Alaska Native;White/Caucasian;Multi-Racial',
#         'American Indian/Native American/Alaska Native;Native Hawaiian/Other Pacific Islander;Multi-Racial',
#         'Asian;Native Hawaiian/Other Pacific Islander',
#         'Hispanic or Latino;Black/African American;White/Caucasian',
#         'Asian;White/Caucasian;Multi-Racial',
#         'White/Caucasian;Choose not to reply',
#         'White/Caucasian;Multi-Racial;Choose not to reply',
#         'Hispanic or Latino;White/Caucasian;Multi-Racial'], dtype=object),
#  array(['CMP 128 Computer Science I', nan,
#         'CMP 239 Internet & Web Page Design',
#         'CMP 131 Fundamentals of Programming (Python)',
#         'CMP 130 Intro to IT',
#         'CMP 120 Foundations of Information Security'], dtype=object))

# %%
# Cleaning and condensing the 'race_ethnicity' column

# Function to group race/ethnicity values
def group_race(race):
    if pd.isnull(race):
        return race
    elif "Multi-Racial" in race or ";" in race:
        return "Multi-Racial"
    elif "Hispanic" in race:
        return "Hispanic or Latino"
    elif "Asian" in race:
        return "Asian"
    elif "White/Caucasian" in race:
        return "White/Caucasian"
    elif "Black/African American" in race:
        return "Black/African American"
    elif "American Indian/Native American/Alaska Native" in race:
        return "Native American"
    else:
        return race

# Applying the grouping function to the 'race_ethnicity' column
df_cleaned['race_ethnicity'] = df_cleaned['race_ethnicity'].apply(group_race)

# Checking the updated unique values in 'race_ethnicity'
unique_race_updated = df_cleaned['race_ethnicity'].unique()
unique_race_updated
# Out:
# array(['White/Caucasian', 'Asian', 'Choose not to reply', 'Multi-Racial',
#        'Hispanic or Latino', 'Native American', 'Black/African American'],
#       dtype=object)

# %%
# Cleaning and condensing the 'course_enrolled' column

# Function to group course values
def group_course(course):
    if pd.isnull(course):
        return course
    elif "Computer Science" in course:
        return "Computer Science"
    elif "Programming" in course or "Python" in course:
        return "Programming"
    elif "Internet & Web Page Design" in course:
        return "Web Design"
    elif "Intro to IT" in course:
        return "IT Introduction"
    elif "Information Security" in course:
        return "Information Security"
    else:
        return course

# Applying the grouping function to the 'course_enrolled' column
df_cleaned['course_enrolled'] = df_cleaned['course_enrolled'].apply(group_course)

# Checking the updated unique values in 'course_enrolled'
unique_course_updated = df_cleaned['course_enrolled'].unique()
unique_course_updated
# Out:
# array(['Computer Science', nan, 'Web Design', 'Programming',
#        'IT Introduction', 'Information Security'], dtype=object)

# %%
# Checking for duplicate rows in the dataframe
duplicate_rows = df_cleaned[df_cleaned.duplicated()]

duplicate_rows.shape[0]
# Out:
# 0

# %%
df_cleaned
# Out:
#       course_enrolled heard_from_ccm_web_site heard_from_social_media  \
# 0    Computer Science                     Yes                     Yes
# 1                 NaN                      No                      No
# 2    Computer Science                      No                      No
# 3    Computer Science                      No                      No
# 4    Computer Science                     Yes                      No
# ..                ...                     ...                     ...
# 448  Computer Science                      No                      No
# 449  Computer Science                      No                     Yes
# 450  Computer Science            Don't recall                      No
# 451  Computer Science                      No                      No
# 452  Computer Science                      No                      No
#
#     heard_from_community_event heard_from_family_member_or_friend  \
# 0                          Yes                                Yes
# 1                           No                                 No
# 2                           No                                 No
# 3                          Yes                                 No
# 4                           No                                Yes
# ..                         ...                                ...
# 448                         No                                Yes
# 449                         No                                 No
# 450                         No                                 No
# 451                         No                                Yes
# 452                         No                                Yes
#
#     heard_from_current_ccm_student heard_from_ccm_alumni  \
# 0                               No                    No
# 1                              Yes                    No
# 2                               No                    No
# 3                              Yes                    No
# 4                               No                    No
# ..                             ...                   ...
# 448                             No                   Yes
# 449                             No                    No
# 450                   Don't recall          Don't recall
# 451                             No                    No
# 452                            Yes                   Yes
#
#     heard_from_high_school_teacher heard_from_high_school_counselor  \
# 0                              Yes                              Yes
# 1                               No                               No
# 2                              Yes                              Yes
# 3                               No                               No
# 4                              Yes                               No
# ..                             ...                              ...
# 448                            Yes                              Yes
# 449                             No                               No
# 450                            Yes                              Yes
# 451                             No                               No
# 452                             No                               No
#
#     impact_affordable_cost  ... info_from_high_school_teacher  \
# 0              Some Impact  ...                           Yes
# 1              Some Impact  ...                            No
# 2              High Impact  ...                           NaN
# 3              High Impact  ...                           Yes
# 4                      NaN  ...                            No
# ..                     ...  ...                           ...
# 448            High Impact  ...                            No
# 449            High Impact  ...                            No
# 450            High Impact  ...                  Don't recall
# 451            Some Impact  ...                            No
# 452              No Impact  ...                            No
#
#     info_from_ccm_information_technologies_website info_from_ccm_admissions  \
# 0                                              Yes                      Yes
# 1                                              Yes                       No
# 2                                              NaN                      NaN
# 3                                               No                      Yes
# 4                                               No                       No
# ..                                             ...                      ...
# 448                                             No                       No
# 449                                             No                       No
# 450                                            Yes             Don't recall
# 451                                            Yes                      Yes
# 452                                             No                       No
#
#     info_from_ccm_advisor/counselor major_change_details  \
# 0                               Yes         First Choice
# 1                               Yes         First Choice
# 2                               NaN                  NaN
# 3                                No         First Choice
# 4                                No         First Choice
# ..                              ...                  ...
# 448                              No     exercise science
# 449                              No         First Choice
# 450                              No              Biology
# 451                              No         First Choice
# 452                             Yes         First Choice
#
#     interest_in_computing_classes  \
# 0                             NaN
# 1                             NaN
# 2                             1.0
# 3                             NaN
# 4                             NaN
# ..                            ...
# 448                           NaN
# 449                           NaN
# 450                           NaN
# 451                           NaN
# 452                           NaN
#
#                           reason_interest_in_computing gender  \
# 0                                                  NaN    Man
# 1                                                  NaN    Man
# 2    Im really only taking this class for the requi...  Woman
# 3                                                  NaN    Man
# 4                                                  NaN    Man
# ..                                                 ...    ...
# 448                                                NaN    Man
# 449                                                NaN    Man
# 450                                                NaN    Man
# 451                                                NaN    Man
# 452                                                NaN    Man
#
#              race_ethnicity             age
# 0           White/Caucasian           19-20
# 1           White/Caucasian           25-34
# 2           White/Caucasian           19-20
# 3                     Asian  18 and younger
# 4           White/Caucasian           25-34
# ..                      ...             ...
# 448            Multi-Racial           19-20
# 449      Hispanic or Latino           21-24
# 450            Multi-Racial  18 and younger
# 451         White/Caucasian           19-20
# 452  Black/African American  18 and younger
#
# [453 rows x 31 columns]

# %%
# Save the df_cleaned data into a CSV file.

df_cleaned.to_csv('cleaned_data.csv', index=False)
